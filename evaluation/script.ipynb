# %% [markdown]
# # Evaluation
# This is an evaluation between Centralized Learning and Federated Learning made by using tensorflow framework.
#
# Dataset = UCI HAR (Human Activity Recognition)
#
# 1. Centralized Learning
# - 30 Epochs
# - 30 Clients
# 2. Federated Learning
# - 30 Rounds
# - 30 Clients

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
