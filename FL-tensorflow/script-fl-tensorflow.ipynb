# %%
import flwr as fl
import tensorflow as tf

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
model = tf.keras.applications.MobileNetV2(classes=10, weights=None)
model.compile("adam", "sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
model.weights
# Out:
# [<KerasVariable shape=(3, 3, 3, 32), dtype=float32, path=Conv1/kernel>,
#  <KerasVariable shape=(32,), dtype=float32, path=bn_Conv1/gamma>,
#  <KerasVariable shape=(32,), dtype=float32, path=bn_Conv1/beta>,
#  <KerasVariable shape=(32,), dtype=float32, path=bn_Conv1/moving_mean>,
#  <KerasVariable shape=(32,), dtype=float32, path=bn_Conv1/moving_variance>,
#  <KerasVariable shape=(3, 3, 32, 1), dtype=float32, path=expanded_conv_depthwise/kernel>,
#  <KerasVariable shape=(32,), dtype=float32, path=expanded_conv_depthwise_BN/gamma>,
#  <KerasVariable shape=(32,), dtype=float32, path=expanded_conv_depthwise_BN/beta>,
#  <KerasVariable shape=(32,), dtype=float32, path=expanded_conv_depthwise_BN/moving_mean>,
#  <KerasVariable shape=(32,), dtype=float32, path=expanded_conv_depthwise_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 32, 16), dtype=float32, path=expanded_conv_project/kernel>,
#  <KerasVariable shape=(16,), dtype=float32, path=expanded_conv_project_BN/gamma>,
#  <KerasVariable shape=(16,), dtype=float32, path=expanded_conv_project_BN/beta>,
#  <KerasVariable shape=(16,), dtype=float32, path=expanded_conv_project_BN/moving_mean>,
#  <KerasVariable shape=(16,), dtype=float32, path=expanded_conv_project_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 16, 96), dtype=float32, path=block_1_expand/kernel>,
#  <KerasVariable shape=(96,), dtype=float32, path=block_1_expand_BN/gamma>,
#  <KerasVariable shape=(96,), dtype=float32, path=block_1_expand_BN/beta>,
#  <KerasVariable shape=(96,), dtype=float32, path=block_1_expand_BN/moving_mean>,
#  <KerasVariable shape=(96,), dtype=float32, path=block_1_expand_BN/moving_variance>,
#  <KerasVariable shape=(3, 3, 96, 1), dtype=float32, path=block_1_depthwise/kernel>,
#  <KerasVariable shape=(96,), dtype=float32, path=block_1_depthwise_BN/gamma>,
#  <KerasVariable shape=(96,), dtype=float32, path=block_1_depthwise_BN/beta>,
#  <KerasVariable shape=(96,), dtype=float32, path=block_1_depthwise_BN/moving_mean>,
#  <KerasVariable shape=(96,), dtype=float32, path=block_1_depthwise_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 96, 24), dtype=float32, path=block_1_project/kernel>,
#  <KerasVariable shape=(24,), dtype=float32, path=block_1_project_BN/gamma>,
#  <KerasVariable shape=(24,), dtype=float32, path=block_1_project_BN/beta>,
#  <KerasVariable shape=(24,), dtype=float32, path=block_1_project_BN/moving_mean>,
#  <KerasVariable shape=(24,), dtype=float32, path=block_1_project_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 24, 144), dtype=float32, path=block_2_expand/kernel>,
#  <KerasVariable shape=(144,), dtype=float32, path=block_2_expand_BN/gamma>,
#  <KerasVariable shape=(144,), dtype=float32, path=block_2_expand_BN/beta>,
#  <KerasVariable shape=(144,), dtype=float32, path=block_2_expand_BN/moving_mean>,
#  <KerasVariable shape=(144,), dtype=float32, path=block_2_expand_BN/moving_variance>,
#  <KerasVariable shape=(3, 3, 144, 1), dtype=float32, path=block_2_depthwise/kernel>,
#  <KerasVariable shape=(144,), dtype=float32, path=block_2_depthwise_BN/gamma>,
#  <KerasVariable shape=(144,), dtype=float32, path=block_2_depthwise_BN/beta>,
#  <KerasVariable shape=(144,), dtype=float32, path=block_2_depthwise_BN/moving_mean>,
#  <KerasVariable shape=(144,), dtype=float32, path=block_2_depthwise_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 144, 24), dtype=float32, path=block_2_project/kernel>,
#  <KerasVariable shape=(24,), dtype=float32, path=block_2_project_BN/gamma>,
#  <KerasVariable shape=(24,), dtype=float32, path=block_2_project_BN/beta>,
#  <KerasVariable shape=(24,), dtype=float32, path=block_2_project_BN/moving_mean>,
#  <KerasVariable shape=(24,), dtype=float32, path=block_2_project_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 24, 144), dtype=float32, path=block_3_expand/kernel>,
#  <KerasVariable shape=(144,), dtype=float32, path=block_3_expand_BN/gamma>,
#  <KerasVariable shape=(144,), dtype=float32, path=block_3_expand_BN/beta>,
#  <KerasVariable shape=(144,), dtype=float32, path=block_3_expand_BN/moving_mean>,
#  <KerasVariable shape=(144,), dtype=float32, path=block_3_expand_BN/moving_variance>,
#  <KerasVariable shape=(3, 3, 144, 1), dtype=float32, path=block_3_depthwise/kernel>,
#  <KerasVariable shape=(144,), dtype=float32, path=block_3_depthwise_BN/gamma>,
#  <KerasVariable shape=(144,), dtype=float32, path=block_3_depthwise_BN/beta>,
#  <KerasVariable shape=(144,), dtype=float32, path=block_3_depthwise_BN/moving_mean>,
#  <KerasVariable shape=(144,), dtype=float32, path=block_3_depthwise_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 144, 32), dtype=float32, path=block_3_project/kernel>,
#  <KerasVariable shape=(32,), dtype=float32, path=block_3_project_BN/gamma>,
#  <KerasVariable shape=(32,), dtype=float32, path=block_3_project_BN/beta>,
#  <KerasVariable shape=(32,), dtype=float32, path=block_3_project_BN/moving_mean>,
#  <KerasVariable shape=(32,), dtype=float32, path=block_3_project_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 32, 192), dtype=float32, path=block_4_expand/kernel>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_4_expand_BN/gamma>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_4_expand_BN/beta>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_4_expand_BN/moving_mean>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_4_expand_BN/moving_variance>,
#  <KerasVariable shape=(3, 3, 192, 1), dtype=float32, path=block_4_depthwise/kernel>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_4_depthwise_BN/gamma>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_4_depthwise_BN/beta>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_4_depthwise_BN/moving_mean>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_4_depthwise_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 192, 32), dtype=float32, path=block_4_project/kernel>,
#  <KerasVariable shape=(32,), dtype=float32, path=block_4_project_BN/gamma>,
#  <KerasVariable shape=(32,), dtype=float32, path=block_4_project_BN/beta>,
#  <KerasVariable shape=(32,), dtype=float32, path=block_4_project_BN/moving_mean>,
#  <KerasVariable shape=(32,), dtype=float32, path=block_4_project_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 32, 192), dtype=float32, path=block_5_expand/kernel>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_5_expand_BN/gamma>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_5_expand_BN/beta>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_5_expand_BN/moving_mean>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_5_expand_BN/moving_variance>,
#  <KerasVariable shape=(3, 3, 192, 1), dtype=float32, path=block_5_depthwise/kernel>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_5_depthwise_BN/gamma>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_5_depthwise_BN/beta>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_5_depthwise_BN/moving_mean>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_5_depthwise_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 192, 32), dtype=float32, path=block_5_project/kernel>,
#  <KerasVariable shape=(32,), dtype=float32, path=block_5_project_BN/gamma>,
#  <KerasVariable shape=(32,), dtype=float32, path=block_5_project_BN/beta>,
#  <KerasVariable shape=(32,), dtype=float32, path=block_5_project_BN/moving_mean>,
#  <KerasVariable shape=(32,), dtype=float32, path=block_5_project_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 32, 192), dtype=float32, path=block_6_expand/kernel>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_6_expand_BN/gamma>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_6_expand_BN/beta>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_6_expand_BN/moving_mean>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_6_expand_BN/moving_variance>,
#  <KerasVariable shape=(3, 3, 192, 1), dtype=float32, path=block_6_depthwise/kernel>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_6_depthwise_BN/gamma>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_6_depthwise_BN/beta>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_6_depthwise_BN/moving_mean>,
#  <KerasVariable shape=(192,), dtype=float32, path=block_6_depthwise_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 192, 64), dtype=float32, path=block_6_project/kernel>,
#  <KerasVariable shape=(64,), dtype=float32, path=block_6_project_BN/gamma>,
#  <KerasVariable shape=(64,), dtype=float32, path=block_6_project_BN/beta>,
#  <KerasVariable shape=(64,), dtype=float32, path=block_6_project_BN/moving_mean>,
#  <KerasVariable shape=(64,), dtype=float32, path=block_6_project_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 64, 384), dtype=float32, path=block_7_expand/kernel>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_7_expand_BN/gamma>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_7_expand_BN/beta>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_7_expand_BN/moving_mean>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_7_expand_BN/moving_variance>,
#  <KerasVariable shape=(3, 3, 384, 1), dtype=float32, path=block_7_depthwise/kernel>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_7_depthwise_BN/gamma>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_7_depthwise_BN/beta>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_7_depthwise_BN/moving_mean>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_7_depthwise_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 384, 64), dtype=float32, path=block_7_project/kernel>,
#  <KerasVariable shape=(64,), dtype=float32, path=block_7_project_BN/gamma>,
#  <KerasVariable shape=(64,), dtype=float32, path=block_7_project_BN/beta>,
#  <KerasVariable shape=(64,), dtype=float32, path=block_7_project_BN/moving_mean>,
#  <KerasVariable shape=(64,), dtype=float32, path=block_7_project_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 64, 384), dtype=float32, path=block_8_expand/kernel>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_8_expand_BN/gamma>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_8_expand_BN/beta>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_8_expand_BN/moving_mean>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_8_expand_BN/moving_variance>,
#  <KerasVariable shape=(3, 3, 384, 1), dtype=float32, path=block_8_depthwise/kernel>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_8_depthwise_BN/gamma>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_8_depthwise_BN/beta>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_8_depthwise_BN/moving_mean>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_8_depthwise_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 384, 64), dtype=float32, path=block_8_project/kernel>,
#  <KerasVariable shape=(64,), dtype=float32, path=block_8_project_BN/gamma>,
#  <KerasVariable shape=(64,), dtype=float32, path=block_8_project_BN/beta>,
#  <KerasVariable shape=(64,), dtype=float32, path=block_8_project_BN/moving_mean>,
#  <KerasVariable shape=(64,), dtype=float32, path=block_8_project_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 64, 384), dtype=float32, path=block_9_expand/kernel>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_9_expand_BN/gamma>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_9_expand_BN/beta>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_9_expand_BN/moving_mean>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_9_expand_BN/moving_variance>,
#  <KerasVariable shape=(3, 3, 384, 1), dtype=float32, path=block_9_depthwise/kernel>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_9_depthwise_BN/gamma>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_9_depthwise_BN/beta>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_9_depthwise_BN/moving_mean>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_9_depthwise_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 384, 64), dtype=float32, path=block_9_project/kernel>,
#  <KerasVariable shape=(64,), dtype=float32, path=block_9_project_BN/gamma>,
#  <KerasVariable shape=(64,), dtype=float32, path=block_9_project_BN/beta>,
#  <KerasVariable shape=(64,), dtype=float32, path=block_9_project_BN/moving_mean>,
#  <KerasVariable shape=(64,), dtype=float32, path=block_9_project_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 64, 384), dtype=float32, path=block_10_expand/kernel>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_10_expand_BN/gamma>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_10_expand_BN/beta>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_10_expand_BN/moving_mean>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_10_expand_BN/moving_variance>,
#  <KerasVariable shape=(3, 3, 384, 1), dtype=float32, path=block_10_depthwise/kernel>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_10_depthwise_BN/gamma>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_10_depthwise_BN/beta>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_10_depthwise_BN/moving_mean>,
#  <KerasVariable shape=(384,), dtype=float32, path=block_10_depthwise_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 384, 96), dtype=float32, path=block_10_project/kernel>,
#  <KerasVariable shape=(96,), dtype=float32, path=block_10_project_BN/gamma>,
#  <KerasVariable shape=(96,), dtype=float32, path=block_10_project_BN/beta>,
#  <KerasVariable shape=(96,), dtype=float32, path=block_10_project_BN/moving_mean>,
#  <KerasVariable shape=(96,), dtype=float32, path=block_10_project_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 96, 576), dtype=float32, path=block_11_expand/kernel>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_11_expand_BN/gamma>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_11_expand_BN/beta>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_11_expand_BN/moving_mean>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_11_expand_BN/moving_variance>,
#  <KerasVariable shape=(3, 3, 576, 1), dtype=float32, path=block_11_depthwise/kernel>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_11_depthwise_BN/gamma>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_11_depthwise_BN/beta>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_11_depthwise_BN/moving_mean>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_11_depthwise_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 576, 96), dtype=float32, path=block_11_project/kernel>,
#  <KerasVariable shape=(96,), dtype=float32, path=block_11_project_BN/gamma>,
#  <KerasVariable shape=(96,), dtype=float32, path=block_11_project_BN/beta>,
#  <KerasVariable shape=(96,), dtype=float32, path=block_11_project_BN/moving_mean>,
#  <KerasVariable shape=(96,), dtype=float32, path=block_11_project_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 96, 576), dtype=float32, path=block_12_expand/kernel>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_12_expand_BN/gamma>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_12_expand_BN/beta>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_12_expand_BN/moving_mean>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_12_expand_BN/moving_variance>,
#  <KerasVariable shape=(3, 3, 576, 1), dtype=float32, path=block_12_depthwise/kernel>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_12_depthwise_BN/gamma>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_12_depthwise_BN/beta>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_12_depthwise_BN/moving_mean>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_12_depthwise_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 576, 96), dtype=float32, path=block_12_project/kernel>,
#  <KerasVariable shape=(96,), dtype=float32, path=block_12_project_BN/gamma>,
#  <KerasVariable shape=(96,), dtype=float32, path=block_12_project_BN/beta>,
#  <KerasVariable shape=(96,), dtype=float32, path=block_12_project_BN/moving_mean>,
#  <KerasVariable shape=(96,), dtype=float32, path=block_12_project_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 96, 576), dtype=float32, path=block_13_expand/kernel>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_13_expand_BN/gamma>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_13_expand_BN/beta>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_13_expand_BN/moving_mean>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_13_expand_BN/moving_variance>,
#  <KerasVariable shape=(3, 3, 576, 1), dtype=float32, path=block_13_depthwise/kernel>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_13_depthwise_BN/gamma>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_13_depthwise_BN/beta>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_13_depthwise_BN/moving_mean>,
#  <KerasVariable shape=(576,), dtype=float32, path=block_13_depthwise_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 576, 160), dtype=float32, path=block_13_project/kernel>,
#  <KerasVariable shape=(160,), dtype=float32, path=block_13_project_BN/gamma>,
#  <KerasVariable shape=(160,), dtype=float32, path=block_13_project_BN/beta>,
#  <KerasVariable shape=(160,), dtype=float32, path=block_13_project_BN/moving_mean>,
#  <KerasVariable shape=(160,), dtype=float32, path=block_13_project_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 160, 960), dtype=float32, path=block_14_expand/kernel>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_14_expand_BN/gamma>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_14_expand_BN/beta>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_14_expand_BN/moving_mean>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_14_expand_BN/moving_variance>,
#  <KerasVariable shape=(3, 3, 960, 1), dtype=float32, path=block_14_depthwise/kernel>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_14_depthwise_BN/gamma>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_14_depthwise_BN/beta>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_14_depthwise_BN/moving_mean>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_14_depthwise_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 960, 160), dtype=float32, path=block_14_project/kernel>,
#  <KerasVariable shape=(160,), dtype=float32, path=block_14_project_BN/gamma>,
#  <KerasVariable shape=(160,), dtype=float32, path=block_14_project_BN/beta>,
#  <KerasVariable shape=(160,), dtype=float32, path=block_14_project_BN/moving_mean>,
#  <KerasVariable shape=(160,), dtype=float32, path=block_14_project_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 160, 960), dtype=float32, path=block_15_expand/kernel>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_15_expand_BN/gamma>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_15_expand_BN/beta>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_15_expand_BN/moving_mean>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_15_expand_BN/moving_variance>,
#  <KerasVariable shape=(3, 3, 960, 1), dtype=float32, path=block_15_depthwise/kernel>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_15_depthwise_BN/gamma>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_15_depthwise_BN/beta>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_15_depthwise_BN/moving_mean>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_15_depthwise_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 960, 160), dtype=float32, path=block_15_project/kernel>,
#  <KerasVariable shape=(160,), dtype=float32, path=block_15_project_BN/gamma>,
#  <KerasVariable shape=(160,), dtype=float32, path=block_15_project_BN/beta>,
#  <KerasVariable shape=(160,), dtype=float32, path=block_15_project_BN/moving_mean>,
#  <KerasVariable shape=(160,), dtype=float32, path=block_15_project_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 160, 960), dtype=float32, path=block_16_expand/kernel>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_16_expand_BN/gamma>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_16_expand_BN/beta>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_16_expand_BN/moving_mean>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_16_expand_BN/moving_variance>,
#  <KerasVariable shape=(3, 3, 960, 1), dtype=float32, path=block_16_depthwise/kernel>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_16_depthwise_BN/gamma>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_16_depthwise_BN/beta>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_16_depthwise_BN/moving_mean>,
#  <KerasVariable shape=(960,), dtype=float32, path=block_16_depthwise_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 960, 320), dtype=float32, path=block_16_project/kernel>,
#  <KerasVariable shape=(320,), dtype=float32, path=block_16_project_BN/gamma>,
#  <KerasVariable shape=(320,), dtype=float32, path=block_16_project_BN/beta>,
#  <KerasVariable shape=(320,), dtype=float32, path=block_16_project_BN/moving_mean>,
#  <KerasVariable shape=(320,), dtype=float32, path=block_16_project_BN/moving_variance>,
#  <KerasVariable shape=(1, 1, 320, 1280), dtype=float32, path=Conv_1/kernel>,
#  <KerasVariable shape=(1280,), dtype=float32, path=Conv_1_bn/gamma>,
#  <KerasVariable shape=(1280,), dtype=float32, path=Conv_1_bn/beta>,
#  <KerasVariable shape=(1280,), dtype=float32, path=Conv_1_bn/moving_mean>,
#  <KerasVariable shape=(1280,), dtype=float32, path=Conv_1_bn/moving_variance>,
#  <KerasVariable shape=(1280, 10), dtype=float32, path=predictions/kernel>,
#  <KerasVariable shape=(10,), dtype=float32, path=predictions/bias>]
